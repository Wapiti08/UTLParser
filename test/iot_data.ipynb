# %%
import sys
from pathlib import Path
sys.path.append(Path(sys.path[0]).resolve().parent.as_posix())
import pandas as pd
import dask.dataframe as dd
import dask
from zat.log_to_dataframe import LogToDataFrame
# Out:
# ['d:\\Supply Chain\\GraphTrace\\test', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\\python38.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\\lib', 'C:\\Users\\tzrzh\\AppData\\Local\\Microsoft\\WindowsApps\\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0', 'd:\\Supply Chain\\GraphTrace\\env', '', 'd:\\Supply Chain\\GraphTrace\\env\\lib\\site-packages', 'd:\\Supply Chain\\GraphTrace\\env\\lib\\site-packages\\win32', 'd:\\Supply Chain\\GraphTrace\\env\\lib\\site-packages\\win32\\lib', 'd:\\Supply Chain\\GraphTrace\\env\\lib\\site-packages\\Pythonwin', 'D:/Supply Chain/GraphTrace']

# %%
root_path = Path(sys.path[0]).resolve().parent

# %%
test_file_path = root_path.joinpath('data\IoT\iot_23_datasets\iot_23_datasets_small\IoTScenarios','CTU-IoT-Malware-Capture-1-1\\bro\conn.log.labeled')

# %%
log_to_df = LogToDataFrame()
# pd.read_csv(test_file_path).head()#
conn_df = log_to_df.create_dataframe(test_file_path.as_posix())

# %%
conn_df.columns
# Out:
# Index(['uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'proto',
#        'service', 'duration', 'orig_bytes', 'resp_bytes', 'conn_state',
#        'local_orig', 'local_resp', 'missed_bytes', 'history', 'orig_pkts',
#        'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes',
#        'tunnel_parents   label   detailed-label'],
#       dtype='object')

# %%
conn_df['tunnel_parents   label   detailed-label'].value_counts()
# Out:
# tunnel_parents   label   detailed-label
# (empty)   Malicious   PartOfAHorizontalPortScan    539465
# (empty)   Benign   -                               469275
# (empty)   Malicious   C&C                               8
# Name: count, dtype: int64

# %%
conn_df[conn_df['tunnel_parents   label   detailed-label']=="(empty)   Malicious   C&C"]
# Out:
#                                               uid  ... tunnel_parents   label   detailed-label
# ts                                                 ...
# 2018-05-10 10:19:11.001579008  CuWWUt38HMkgdrW5c7  ...               (empty)   Malicious   C&C
# 2018-05-10 11:59:34.013369088    CQRSptR7eBxmPBOL  ...               (empty)   Malicious   C&C
# 2018-05-10 20:47:53.007803904  CsrU6G4nTntOckB5cf  ...               (empty)   Malicious   C&C
# 2018-05-11 01:31:38.011346176  Csmyys1x1gOpBGpr2l  ...               (empty)   Malicious   C&C
# 2018-05-11 09:10:02.011830016  CtxUYp4jsmuZGDeDr6  ...               (empty)   Malicious   C&C
# 2018-05-11 10:10:28.002497024  CjPsHZ2hz94c6ytBVl  ...               (empty)   Malicious   C&C
# 2018-05-11 23:25:05.013474816  CMkJbX3lFDiEy85wLd  ...               (empty)   Malicious   C&C
# 2018-05-13 17:39:59.024442880  CWunXh1wIbr1DN6Cw4  ...               (empty)   Malicious   C&C
#
# [8 rows x 20 columns]
