# %%
import sys
from pathlib import Path
sys.path.append(Path(sys.path[0]).resolve().parent.as_posix())
import pandas as pd
import dask.dataframe as dd
import dask
from zat.log_to_dataframe import LogToDataFrame

# %%
root_path = Path(sys.path[0]).resolve().parent

# %%
test_file_path = root_path.joinpath('data\IoT\iot_23_datasets\iot_23_datasets_small\IoTScenarios','CTU-IoT-Malware-Capture-35-1\\bro\conn.log.labeled')

# %%
log_to_df = LogToDataFrame()
# pd.read_csv(test_file_path).head()#
conn_df = log_to_df.create_dataframe(test_file_path.as_posix(),ts_index=False)

# %%
conn_df.columns
# Out:
# Index(['ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p',
#        'proto', 'service', 'duration', 'orig_bytes', 'resp_bytes',
#        'conn_state', 'local_orig', 'local_resp', 'missed_bytes', 'history',
#        'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes',
#        'tunnel_parents   label   detailed-label'],
#       dtype='object')

# %%
conn_df['tunnel_parents   label   detailed-label'].value_counts()
# Out:
# tunnel_parents   label   detailed-label
# -   Benign   -                      8262389
# -   Malicious   DDoS                2185302
# -   Malicious   C&C                      81
# -   Malicious   C&C-FileDownload         12
# -   Malicious   Attack                    3
# Name: count, dtype: int64

# %%
conn_df['tunnel_parents   label   detailed-label'].value_counts().keys()
# Out:
# CategoricalIndex(['-   Benign   -', '-   Malicious   DDoS',
#                   '-   Malicious   C&C', '-   Malicious   C&C-FileDownload',
#                   '-   Malicious   Attack'],
#                  categories=['-   Benign   -', '-   Malicious   C&C', '-   Malicious   C&C-FileDownload', '-   Malicious   Attack', '-   Malicious   DDoS'], ordered=False, dtype='category', name='tunnel_parents   label   detailed-label')

# %%
conn_df[conn_df['tunnel_parents   label   detailed-label']=="-   Malicious   C&C-FileDownload"]
# Out:
#                                               uid      id.orig_h  id.orig_p  \
# ts
# 2018-12-21 14:36:15.921971200    CQSI8MuXCL4tsc5n  192.168.1.196      59934
# 2018-12-21 14:39:33.961536000  CVruoh4LgNAcBKjHkj  192.168.1.196      59938
# 2018-12-21 14:41:55.961308928  C3jWCS12n4Er3wypof  192.168.1.196      59942
# 2018-12-21 14:42:03.961249024  CFBkJX1PUJ8h6mnxFi  192.168.1.196      59944
# 2018-12-21 14:42:04.804016128  C6t8wg4MzHi2cBWbHi  192.168.1.196      59946
# 2018-12-21 14:55:43.161832960  CCIwry3ikg30WliNo3  192.168.1.196      44822
# 2018-12-21 14:55:45.147972096  CYsfGZ2Zkxx85hi4B3  192.168.1.196      44850
# 2018-12-21 14:56:52.681297920  CJ8CZC2lMbDVb0mnI7  192.168.1.196      44884
# 2018-12-21 15:01:29.401758976  CdjjA64S7xKIUzhUmg  192.168.1.196      48994
# 2018-12-21 15:01:30.322479872   CfBarntmORHTKInkb  192.168.1.196      49034
# 2018-12-21 15:01:48.361705984   CfCMECz1pG817B6qb  192.168.1.196      49064
# ...

# %%
conn_df.head()
# Out:
#                                               uid      id.orig_h  id.orig_p  \
# ts
# 2018-12-21 14:34:02.863611904  CdNmOg26ZIaBRzPvWj  192.168.1.196      59932
# 2018-12-21 14:34:10.041294080  CgzGV333k9WCximeu8  192.168.1.196      59932
# 2018-12-21 14:34:18.441478912  CLm5Pd3ZnqmYVjrZ44  192.168.1.196      59932
# 2018-12-21 14:34:13.913069056  CDn2pd1rDD1lCMXAia  192.168.1.196      35883
# 2018-12-21 14:34:03.902540032  C1NKkV3tB4rImzbpDj  192.168.1.196      43531
#
#                                     id.resp_h  id.resp_p proto service  \
# ts
# 2018-12-21 14:34:02.863611904  104.248.160.24         80   tcp     NaN
# 2018-12-21 14:34:10.041294080  104.248.160.24         80   tcp     NaN
# 2018-12-21 14:34:18.441478912  104.248.160.24         80   tcp     NaN
# 2018-12-21 14:34:13.913069056     192.168.1.1         53   udp     dns
# 2018-12-21 14:34:03.902540032     192.168.1.1         53   udp     dns
#
# ...

# %%
conn_df[conn_df['tunnel_parents   label   detailed-label']=="-   Malicious   Attack"]
# Out:
#                                               uid      id.orig_h  id.orig_p  \
# ts
# 2018-12-21 16:52:05.004110080   CZvpgd2NwLnJOQJax  192.168.1.196      43588
# 2018-12-21 18:42:04.058324224  CtfsYg458ajU9N12ka  192.168.1.196      34966
# 2018-12-21 18:42:11.238477824  CWj7Ho224zoHE97tW3  192.168.1.196      34966
#
#                                     id.resp_h  id.resp_p proto service  \
# ts
# 2018-12-21 16:52:05.004110080  110.183.76.177         23   tcp     NaN
# 2018-12-21 18:42:04.058324224    112.27.30.87         23   tcp     NaN
# 2018-12-21 18:42:11.238477824    112.27.30.87         23   tcp     NaN
#
#                                             duration  orig_bytes  resp_bytes  \
# ts
# 2018-12-21 16:52:05.004110080 0 days 00:01:16.692814        1246         690
# 2018-12-21 18:42:04.058324224 0 days 00:00:03.100238           0           0
# 2018-12-21 18:42:11.238477824 0 days 00:00:52.457363         424          57
#
# ...

# %%
conn_df['id.orig_h'].value_counts()
# Out:
# id.orig_h
# 192.168.1.196      10446132
# 223.118.3.106             6
# 204.115.183.4             5
# 64.57.28.2                5
# 200.0.204.218             4
#                      ...
# 140.186.170.118           1
# 81.17.139.25              1
# 79.28.36.83               1
# 200.146.83.93             1
# 200.170.187.33            1
# Name: count, Length: 1556, dtype: int64

# %%
# build graphs f

# %%
test_file_path = root_path.joinpath('data\IoT\iot_23_datasets\iot_23_datasets_small\IoTScenarios','CTU-IoT-Malware-Capture-35-1\\bro\conn.log.labeled')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Supply Chain\GraphTrace\test\iot_data.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Supply%20Chain/GraphTrace/test/iot_data.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> test_file_path = root_path.joinpath('data\IoT\iot_23_datasets\iot_23_datasets_small\IoTScenarios','CTU-IoT-Malware-Capture-35-1\\bro\conn.log.labeled')
#
# NameError: name 'root_path' is not defined
